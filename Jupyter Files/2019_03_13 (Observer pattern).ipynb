# %%
# Observer Pattern with Polling

from ui import *

class Independent:
    a = 10
    def Add(self, tmp):
        Independent.a += 1

class Dependent1:
    def __init__(self):
        self.a = Independent.a
    
    def Update(self):
        if Independent.a != self.a:
            self.a = Independent.a
            print("New Number: " + str(self.a))

class Dependent2:
    def __init__(self):
        self.a = Independent.a
    
    def Update(self):
        if Independent.a != self.a:
            print("Last Number: " + str(self.a))
            self.a = Independent.a

i = Independent();

root = Tk()
f = UIFrame(root=root)
b = UIButton(i.Add, text="Add", bg="green")
f.Add(b, side=LEFT)

d1 = Dependent1()
d2 = Dependent2()

def Update():
    d1.Update()
    d2.Update()
    root.after(10, Update)

root.after(10, Update)
root.mainloop()

# %%
# Observer Pattern with Callbacks

from ui import *

class Independent:
    a = 10
    callbacks = []
    def Add(self, tmp):
        Independent.a += 1
        for i in Independent.callbacks:
            i()
    
    @classmethod
    def RegisterCallback(cls, callback):
        cls.callbacks.append(callback)

class Dependent1:
    def Callback(self):
        print("New Number: " + str(Independent.a))

class Dependent2:
    def __init__(self):
        self.a = Independent.a
    
    def Callback(self):
        print("Last Number: " + str(self.a))
        self.a = Independent.a

i = Independent();

root = Tk()
f = UIFrame(root=root)
b = UIButton(i.Add, text="Add", bg="green")
f.Add(b, side=LEFT)

d1 = Dependent1()
Independent.RegisterCallback(d1.Callback)
d2 = Dependent2()
Independent.RegisterCallback(d2.Callback)

root.mainloop()
